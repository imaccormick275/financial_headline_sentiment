# %% [markdown]
# # AssociationRules with HierarchicalClassification
#
# * Implementation: scripts/association_rules.py
# * Implementation: scripts/hierarchical_classifier.py
#
# Hierarchical classifier used to adress neutral vs polarised classifcation.

# %% [markdown]
# ## Import Libraries

# %%
# set sys path to access scripts
import sys
sys.path.append('../')

# general
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# model
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import scripts.association_rules as association_rules
import scripts.hierarchical_classifier as hierarchical_classifier

# custom scripts
import scripts.evaluator as evaluator
import scripts.config as config
from scripts.helpers import get_regex
from scripts.helpers import split_sentence
from scripts.helpers import list_to_comma_sep_string
from scripts.helpers import list_to_string
from scripts.helpers import pos_tagging
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Import Data

# %%
df_phrase = pd.read_csv(config.FINANCIAL_PHRASE_BANK)
df_domain_dict = pd.read_csv(config.DOMAIN_DICTIONARY)

df_phrase['tags'] = df_phrase['tags'].replace(np.NaN,'')

# %% [markdown]
# ## Create Train/Test Sets, Define Model, Train, Test

# %%
# test train split
X_train, X_test, y_train, y_test = train_test_split(df_phrase['tags'], 
                                                    df_phrase['sentiment'], 
                                                    test_size=config.TEST_SIZE, 
                                                    random_state=config.RANDOM_STATE)

# reset indicies -- required for heirachical classifier
# comparisson of models misclassified indicies in seperate notebook
# indicies required to be in line accross notebooks
X_train = X_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# model
model_1 = association_rules.association_classifier(0.005,0.6,0.0)
model_2 = association_rules.association_classifier(0.005,0.6,0.0)
hclass = hierarchical_classifier.heirarchical_classifier(model_1, model_2, y_test, ['negative','positive'], 'polarized', 'neutral')

# evaluator fits, predicts and returns metrics for model
_eval = evaluator.evaluator('ar & hc', hclass, X_train, y_train, X_test, y_test)
_eval.plot_confusion()
_eval.get_results()
# Out:
#   experiment            result  accuarcy  precision  recall  fscore  \
# 0    ar & hc  cross validation     0.745      0.695   0.728   0.708
# 1    ar & hc              test     0.745      0.702   0.736   0.717
#
#                                    misclass_indicies  \
# 0                                                 []
# 1  [5, 18, 19, 20, 22, 23, 28, 31, 33, 34, 43, 45...
#
#                                          predictions
# 0                                                 []
# 1  [positive, neutral, neutral, neutral, neutral,...

# %%
_eval.save_results('results/results.csv')

# %% [markdown]
# ## Rules Generated

# %%
_eval.model.model_h2.df_association_rules
# Out:
#               antecedents consequent_sentiment  confidence   support  \
# 0           lagging, down            polarized    0.969697  0.008373
# 1     lagging, lagging:up            polarized    0.955224  0.016745
# 2              lagging:up            polarized    0.953571  0.069859
# 3   lagging, lagging:down            polarized    0.952381  0.005233
# 4            lagging:down            polarized    0.941606  0.033752
# 5          up, lagging:up            polarized    0.913043  0.005495
# 6            lagging, neg            polarized    0.907692  0.030874
# 7                                      neutral    0.896425  0.255887
# 8               down, neg            polarized    0.863636  0.009942
# 9            leading:down            polarized    0.862069  0.013082
# 10    lagging, leading:up            polarized    0.833333  0.005233
# 11           lagging, pos            polarized    0.822785  0.017007
# 12            lagging, up            polarized    0.790123  0.016745
# 13            up, leading            polarized    0.788079  0.031136
# 14                up, pos            polarized    0.763158  0.015175
# 15    leading:up, leading            polarized    0.735294  0.006541
# 16             leading:up            polarized    0.725664  0.021455
# 17                up, neg            polarized    0.682927  0.007326
# 18       lagging, leading              neutral    0.680272  0.026164
# 19                    neg            polarized    0.679707  0.072737
# 20          down, leading            polarized    0.675676  0.006541
# 21                    pos            polarized    0.652482  0.072214
# 22                   down            polarized    0.649425  0.029566
# 23           pos, leading            polarized    0.643411  0.021716
# 24           neg, leading            polarized    0.634615  0.017268
# 25                     up            polarized    0.629412  0.083987
# 26                leading              neutral    0.622403  0.180272
#
#     antecedent_length
# 0                   2
# 1                   2
# 2                   1
# 3                   2
# 4                   1
# 5                   2
# 6                   2
# 7                   1
# 8                   2
# 9                   1
# 10                  2
# 11                  2
# 12                  2
# 13                  2
# 14                  2
# 15                  2
# 16                  1
# 17                  2
# 18                  2
# 19                  1
# 20                  2
# 21                  1
# 22                  1
# 23                  2
# 24                  2
# 25                  1
# 26                  1

# %%
_eval.model.model_h1.df_association_rules
# Out:
#                  antecedents consequent_sentiment  confidence   support  \
# 0              lagging, down             negative    1.000000  0.020645
# 1      lagging, pos, leading             positive    1.000000  0.007097
# 2             up, lagging:up             positive    1.000000  0.013548
# 3      lagging:down, leading             negative    1.000000  0.005161
# 4         lagging, down, neg             negative    1.000000  0.010968
# 5    lagging, up, lagging:up             positive    1.000000  0.005806
# 6          lagging:down, neg             negative    1.000000  0.005161
# 7       lagging, up, leading             positive    1.000000  0.006452
# 8          pos, neg, leading             positive    1.000000  0.005161
# 9               pos, leading             positive    0.975904  0.052258
# 10       lagging, lagging:up             positive    0.968750  0.040000
# 11              lagging:down             negative    0.961240  0.080000
# 12       leading:up, leading             positive    0.960000  0.015484
# 13       lagging, leading:up             positive    0.950000  0.012258
# 14                       pos             positive    0.949275  0.169032
# 15                   up, pos             positive    0.948276  0.035484
# 16                lagging:up             positive    0.947566  0.163226
# 17          pos, up, leading             positive    0.947368  0.011613
# 18       leading, lagging:up             positive    0.937500  0.009677
# 19     leading:down, leading             negative    0.933333  0.009032
# 20            leading:up, up             positive    0.928571  0.008387
# 21                leading:up             positive    0.926829  0.049032
# 22           leading:up, pos             positive    0.923077  0.007742
# 23              lagging, pos             positive    0.923077  0.038710
# 24               lagging, up             positive    0.921875  0.038065
# 25     lagging, lagging:down             negative    0.900000  0.011613
# 26              leading:down             negative    0.900000  0.029032
# 27               up, leading             positive    0.899160  0.069032
# 28                        up             positive    0.897196  0.185806
# 29           neg, lagging:up             positive    0.888889  0.010323
# 30     lagging, leading:down             negative    0.888889  0.005161
# 31             down, leading             negative    0.840000  0.013548
# 32  lagging:down, lagging:up             negative    0.833333  0.006452
# 33                                       positive    0.831858  0.060645
# 34          lagging, leading             positive    0.787234  0.023871
# 35              lagging, neg             negative    0.728814  0.055484
# 36                      down             negative    0.725664  0.052903
# 37                   leading             positive    0.724880  0.195484
# 38              neg, leading             negative    0.712121  0.030323
# 39                                       positive    0.698710  0.698710
# 40                       neg             negative    0.683453  0.122581
# 41                  neg, pos             positive    0.666667  0.006452
# 42                   lagging             positive    0.648379  0.167742
# 43                 down, neg             negative    0.631579  0.015484
# 44                   up, neg             negative    0.607143  0.010968
#
#     antecedent_length
# 0                   2
# 1                   3
# 2                   2
# 3                   2
# 4                   3
# 5                   3
# 6                   2
# 7                   3
# 8                   3
# 9                   2
# 10                  2
# 11                  1
# 12                  2
# 13                  2
# 14                  1
# 15                  2
# 16                  1
# 17                  3
# 18                  2
# 19                  2
# 20                  2
# 21                  1
# 22                  2
# 23                  2
# 24                  2
# 25                  2
# 26                  1
# 27                  2
# 28                  1
# 29                  2
# 30                  2
# 31                  2
# 32                  2
# 33                  1
# 34                  2
# 35                  2
# 36                  1
# 37                  1
# 38                  2
# 39                  0
# 40                  1
# 41                  2
# 42                  1
# 43                  2
# 44                  2
